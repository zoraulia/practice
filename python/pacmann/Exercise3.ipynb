# %% [markdown]
# # 1. Menghitung Luas di Bawah Kurva
# ![trapesium.png](data:image/png;base64,...)<br>
#
# Penghitungan luas di bawah kurva dapat dilakukan dengan membuat partisi-partisi kecil pada kurva dan tiap partisi tersebut dianggap sebuah trapesium. Kemudian luas tiap partisi dari sebuah interval ditambahkan dan hasilnya adalah luas dibawah kurva

# %% [markdown]
# Buatlah fungsi untuk menghitung luas dibawah kurva dengan ketentuan seperti ini:
# ---
# fungsi menghitung luas dibawah kurva
#
# Args:<br>
# - a(int): batas bawah interval
# - b(int): batas atas interval
# - n(int): jumlah partisi
# - persamaan(string): persamaan kurva dengan format "a b c " dimana a adalah koefisien x^2, b adalah koefisien x , dan c adalah konstanta.
#
# Returns:
# - Luas(float) : luas di bawah kurva
# ---
# fungsi mencaari y
#
# Args:<br>
# - persamaan(string): persamaan kurva dengan format "a b c " dimana a adalah koefisien x^2, b adalah koefisien x , dan c adalah konstanta.
# - x(float): nilai yang dimasukkan ke persamaan
#
# Returns:
# - y: nilai y pada x tertentu
#
# Diasumsikan persamaan memiliki koefisien x tertinggi adalah 2. Dengan kata lain persamaan umum dari y adalah
#
# y = ax^2 + bx + c<br>
#
# Contoh:
# Masukkan batas bawah : 1<br>
# Masukkan batas atas : 4<br>
# Masukkan jumlah partisi :4<br>
# Masukkan persamaan :1 1 1<br>
# Luas di bawah kurva:1542.65625

# %%
#Fungsi
def ...(a,b,n,persamaan):
  ...
  ...
  ...

def ...(persamaan,x):
  ...
  ...
  ...

# %%
#Input
a = int(input("Masukkan batas bawah : "))
b = int(input("Masukkan batas atas : "))
n = int(input("Masukkan jumlah partisi :"))
persamaan = input("Masukkan persamaan :")

#Output
...

# %% [markdown]
# # 2. Mencari Kelipatan Persekutuan Terkecil dan Faktor Persekutuan Terbesar

# %% [markdown]
# Kelipatan persekutuan terkecil(KPK) adalah  bilangan bulat positif terkecil yang dapat dibagi habis oleh kedua bilangan itu. Contoh
# - KPK dari 4 dan 6 adalah 12
# - KPK dari 6 dan 5 adalah 30
#
# Faktor persekutuan terbesar adalah bilangan bulat positif terbesar yang dapat membagi habis kedua bilangan itu.
# - FPB dari 30 dan 5 adalah 5
# - FPB dari 18 dan 7 adalah 1
#
# Buatlah sebuah fungsi dengan ketentuan berikut:
# fungsi mencari fpb dan kpk
#
# Args:
# - a(int) : salah satu bilangan bulat yang ingin dicari fpb dan kpknya
# - b(int) : salah satu bilangan bulat yang ingin dicari fpb dan kpknya
#
# Returns:
# - FPB(int) : fpb dari a dan b
# - KPK(int) : kpk dari a dan b
#
# Contoh :<br>
# Masukkan a : 5<br>
# Masukkan b : 6<br>
# FPB dan KPK dari kedua bilangan tersebut adalah : 1 dan 30

# %%
def ...(a,b):
  ...
  ...
  ...

# %%
#Input
a = int(input("Masukkan bilangan pertama"))
b = int(input("Masukkan bilangan kedua"))

#Output
...

# %% [markdown]
# # 3. Mencari Karakter yang Muncul pada Dua Kalimat

# %% [markdown]
# Buatlah fungsi yang dapat mencetak karakter yang muncul pada dua kalimat(interseksi antara dua kalimat):
#
# fungsi mencari interseksi dua kalimat
#
# Args:
# - kalimat_1(str) : kalimat pertama
# - kalimat_2(str) : kalimat kedua
#
# Returns:
# - Mencetak karakter apa saja pada kalimat pertama yang muncul juga di kalimat kedua
#
# Contoh 1:
# kalimat 1 = "abcdef"
# kalimat 2 = "ghijklmnopa"
# interseksi = a
#
# Contoh 2:
# kalimat 1 = "aku pergi ke pasar"
# kalimat 2 = "pasar pergi ke aku"
# interseksi = a k u   p e r g i   k e   p a s a r
#
# Tidak perlu diperhatikan karakter yang muncul berkali-kali jadi tinggal cetak saja jika karakter tersebut muncul pada kalimat kedua

# %%
def ....(kalimat_1, kalimat_2): 
  ...
  ...
  ...

# %%
#Input
kalimat_1 = input("Masukkan kalimat pertama :")
kalimat_2 = input("Masukkan kalimat kedua :")

#Output
...

# %% [markdown]
# # 4.Mencetak Kuadrat ** n Sampai n tertentu

# %% [markdown]
# Buatlah fungsi yang dapat mencetak kuadrat 1 sampai n dari bilangan x dengan mengimplementasikan fungsi lambda untuk perhitungan kuadratnya
#
# fungsi cetak kuadrat ke-n
#
# Args:
# - x(int) : bilangan yang ingin dicari pangkat ke-n nya
# - n(int) : pangkat tertinggi
#
# Returns:
# - Contoh percetakannya dapat dilihat dibawah
#
# Contoh 1:<br>
# Masukkan x : 2<br>
# Masukkan n : 3<br>
# Kuadrat 1 dari 2 adalah 2<br>
# Kuadrat 2 dari 2 adalah 4<br>
# Kuadrat 3 dari 2 adalah 8
#
# Contoh 2:<br>
# Masukkan x : 3<br>
# Masukkan n : 4<br>
# Kuadrat 1 dari 3 adalah 3<br>
# Kuadrat 2 dari 3 adalah 9<br>
# Kuadrat 3 dari 3 adalah 27<br>
# Kuadrat 4 dari 3 adalah 81
#
# Ingat harus mengimplementasikan fungsi lambda untuk mencari pangkat x ke-n

# %%
def ...(x,n):
  #Penghitungan pangkat harus memakai fungsi lambda 
  pangkat = lambda ...,...:
  ...
  ...

# %%
#Input
a = int(input("Masukkan x : "))
b = int(input("Masukkan n : "))

#Output
...
