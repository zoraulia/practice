# %% [markdown]
# Suatu hari Tejo dan Surti bercerita tentang genre musik kesukaan mereka. Dari percakapan tersebut diketahui Tejo menyukai genre musik dangdut, melayu, pop, rock, dan reggae, sedangkan Surti menyukai genre melayu, dangdut, pop, jazz dan klasik. Ateti yang mendengarkan percakapan  tersebut kemudian membuat set dari genre musik kesukaan Tejo dan Tuti, kemudian mencari tahu beberapa hal:
# 1. Genre musik apa saja yang disukai baik oleh Tejo maupun Tuti
# 2. Genre musik apa yang disukai Tuti tapi tidak disukai Tejo
# 3. Genre musik apa saja yang hanya disukai oleh Tejo atau Tuti (buat kedalam sebuah set baru)
# 4. Setelah menanyakan kembali ke Tejo ternyata ia menyukai genre punk rock bukan genre rock (gantilah elemen tersebut).

# %%
genre_tejo = {'dangdut', 'melayu', 'pop', 'rock', 'reggae'}
genre_surti = {'melayu', 'dangdut', 'jazz', 'klasik', 'pop'}

# %% [markdown]
# Ateti sedang membuat daftar film yang akan di tontonnya pada masa libur semester nanti. Daftar film tersebut di susun ke dalam sebuah dictionary. Mula-mula ia mengelompokkan film tersebut berdasarkan genre. Kemudian di setiap genre akan berisi judul dan tahun rilis film tersebut. Sebelum mencetak daftar film tersebut dia melakukan pengecekan dan merubah beberapa hal.
# 1. Mengecek apakah terdapat key judul di setiap genre film
# 2. Mengganti tahun rilis film The Martian menjadi 2015
# 3. menambahkan informasi durasi film:
#    - Jumanji : 1 jam 59 menit
#    - My Stupid Bos : 1 jam 46 menit
#    - The Martian : 2 jam 21 menit
#    - Spiderman Home Coming : 2 jam 13 menit
# 4. Cetak semua judul film fiksi ilmiah yang akan di tonton beserta tahun rilisnya

# %%
daftar_film = {'komedi' : {'judul' : ['Jumanji', 'My Stupid Boss'], 'tahun_rilis' : [2017, 2016]},
              'fiksi ilmiah': {'judul' : ['The Martian', 'Spidermen Home Coming'], 'tahun rilis' :[2017, 2017]}
              }

# %% [markdown]
# Buatlah sebuah fungsi (yang menggunakan konsep rekursif) untuk mengambil elemen dari baris segitiga pascal:
#
# ![pascal.png](attachment:pascal.png)
#
# Contoh : pascal(4) ;  output: [1, 3, 3, 1]
