# %% [markdown]
# # Tugas 2 Probability
#
# * Silakan download dan kerjakan soal berikut dimanapun (laptop pribadi/google colab/etc.)
# * Setelah selesai mengerjakan, upload file ini di tempat yang telah disediakan pada platform.
# * Beri nama file seperti berikut: {username}-probability-2.ipynb
# * Contoh: johndoe-ab12-probability-2.ipynb
# * Tutorial: https://discourse.pacmann.ai/t/pengumuman-seluruh-platform-pacmann-ai/409
# * Username dapat dilihat di dalam akun anda.
# * Mohon jangan mengubah nama variabel yang telah diberikan.
# * Namun anda diperbolehkan untuk menambah variabel apapun.

# %% [markdown]
# 1. Buatlah set dalam python yang berisi nama-nama hari dalam 1 minggu. (Bahasa Indonesia)

# %%
hari = # jawaban
hari
# Out:
# {'jumat', 'kamis', 'minggu', 'rabu', 'sabtu', 'selasa', 'senin'}

# %% [markdown]
# 2. Tentukan irisan antara 2 set berikut dengan menggunakan metode `intersection`

# %%
set_A = {3,4,8,10}
set_B = {4,5,8,11}

irisan = #Jawaban
irisan
# Out:
# {4, 8}

# %% [markdown]
# 3. Dari kata `VOLTAGE` ada berapa kemungkinan untuk penyusunan huruf?

# %%
# Jawaban anda disini
# Out:
# 5040

# %% [markdown]
# 4. Jika pada suatu perlombaan terdapat 10 anak dan diasumsikan semua anak memiliki kemampuan yang sama. Ada berapa cara kemungkinan untuk urutan juara 1,2 dan 3?

# %%
# Anda dipersilakan untuk memakai metode apapun
# Out:
# 720.0

# %% [markdown]
# 5. Dari 8 konsonan dan 4 vokal, ada berapa kata yang dapat dibentuk dari 3 konsonan dan 2 vokal?

# %%
# Anda dipersilakan untuk memakai metode apapun
# Out:
# 40320.0

# %% [markdown]
# 6. Diberikan dadu 6 sisi yang diwakilkan sebagai list angka. Lakukanlah simulasi pelemparan dadu 100000 kali. Kemudian cek berapa probabilitas untuk keluar angka 4 dari dadu tersebut.

# %%
# Untuk simulasi pelemparan dadu, anda dipersilakan untuk googling solusinya
# Anda juga dipersilakan untuk menggunakan metode apapun
# Out:
# 0.1661

# %% [markdown]
# 7. Sebuah dadu 6 sisi dilempar sebanyak 4 kali. Berapakah kemungkinan jumlah dari semua angka yang keluar dari 4 pelemparan tadi memiliki jumlah 15? Hint: Gunakan itertools.product untuk membuat sample space

# %%
# Untuk simulasi pelemparan dadu, anda dipersilakan untuk googling solusinya
# Anda juga dipersilakan untuk menggunakan metode apapun
# Out:
# 0.10802469135802469

# %% [markdown]
# 8. Sebuah dadu dilempar 1 kali. Tentukan peluang mata dadu 2 muncul dengan syarat mata dadu yang muncul adalah bilangan genap.

# %%
# Tulis kode anda disini
# Out:
# {2, 4, 6}
# {2}
# P(2 muncul | genap): 0.3333333333333333

# %% [markdown]
# 9. Sebuah mesin memproduksi bagian yang bagus sebesar 90%, sedikit cacat 2%, dan yang benar-benar cacat 8%. Bagian yang diproduksi melewati mesin inspeksi otomatis, yang mampu mendeteksi bagian mana yang benar-benar cacat dan membuangnya. Berapa peluang bagian yang dikirim dengan syarat lolos inspeksi?

# %%
# Tulis kode anda disini
# Out:
# Peluang bagian tersebut dikirim dengan syarat lolos inspeksi adalah 0.9782608695652174
