# %% [markdown]
# # **TUGAS 2**
#
# Materi:
# - Linear Functions
# - Norm and Distances

# %%
# Jalankan kode berikut untuk import library NumPy
import numpy as np

# %% [markdown]
# ---
# **Soal 5**
#
# Hitung norm dari vektor berikut $A = (3, 5, 3)$

# %%
# Buat vektor A
A = ...

# %%
# Hitung norm A
norm_A = ...

# %% [markdown]
# ---
# ## **Performa Posting Medsos Baru**
#
# ![source](http://blog.clickdimensions.com/wp-content/uploads/2017/10/BlogFeatureImage-12-Types-of-Content-to-Post-on-Social-Media.png)
#
# Performa posting dari media sosial dapat dilihat dari beberapa parameter antara lain:
# - jumlah likes
# - jumlah shares
# - jumlah saved
#
# ---

# %% [markdown]
# - Posting dikatakan **bagus**, apabila kisaran jumlah:
#    - likes = 50
#    - shares = 75
#    - saved = 50
#
# - Posting dikatakan **biasa**, apabila kisaran jumlah:
#    - likes = 250
#    - shares = 10
#    - saved = 20
#
# - dan Posting dikatakan **kurang**, apabila kisaran jumlah:
#    - likes = 100
#    - shares = 5
#    - saved = 10

# %% [markdown]
# Apabila post terbaru Ferio memiliki nilai parameter sebagai berikut:
# - likes = 50
# - shares = 25
# - saved = 27
#
#
# Bantu tentukan kategori post terbaru Ferio

# %% [markdown]
# ---
# **Soal 6**
# - Tuliskan langkah yang Anda lakukan dalam menjawab pertanyaan tersebut.

# %%
langkah = """
- ceritakan langkah-langkah dalam blok ini.
- ceritakan dalam bentuk poin.
"""

# %% [markdown]
# ---
# **Soal 7**
#
# - Pertama, buat vektor kategori post bagus, post biasa, post kurang, dan post Ferio dengan parameter post seperti pada soal. (Parameter berurutan: jumlah likes, shares, dan saved)

# %%
post_bagus = ...
post_biasa = ...
post_kurang = ...
post_ferio = ...

# %% [markdown]
# ---
# **Soal 8**
#
# - Cari jarak (Euclidean distance) antara post Ferio dengan masing-masing kategori post

# %%
jarak_bagus = ...
jarak_biasa = ...
jarak_kurang = ...

# %% [markdown]
# ---
# **Soal 9**
#
# - Tentukan kategori dari post terbaru Ferio (Hint: berdasarkan jarak yang didapat dari soal no. 8)

# %%
kategori_post = ['bagus', 'biasa', 'kurang']
kategori_ferio = ...

# %% [markdown]
# ---
# **Soal 10**
#
# - Apakah penggunaan jarak Euclidean tepat untuk menjawab soal ini?
# - Tuliskan alasannya.

# %%
alasan = """
- Tuliskan alasan dalam bentuk point
- Tuliskan alasan dalam bentuk point
"""
